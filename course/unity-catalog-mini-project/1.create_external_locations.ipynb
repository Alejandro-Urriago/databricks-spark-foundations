-- %% [markdown]
-- ### Create the external locations required for this project
--
-- 1. Bronze
-- 1. Silver
-- 1. Gold

-- %%
%sql

CREATE EXTERNAL LOCATION IF NOT EXISTS alejandroauedevdl_bronze
URL 'abfss://bronze@alejandroauedevdl.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `alejandro_uc_access`);

-- %%
DESC EXTERNAL LOCATION alejandroauedevdl_bronze

-- %%
%fs

ls 'abfss://bronze@alejandroauedevdl.dfs.core.windows.net/'

-- %%
%sql

CREATE EXTERNAL LOCATION IF NOT EXISTS alejandroauedevdl_silver
URL 'abfss://silver@alejandroauedevdl.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `alejandro_uc_access`);

-- %%
%sql

CREATE EXTERNAL LOCATION IF NOT EXISTS alejandroauedevdl_gold
URL 'abfss://gold@alejandroauedevdl.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `alejandro_uc_access`);
